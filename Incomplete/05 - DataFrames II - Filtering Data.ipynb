# %% [markdown]
# # DataFrames II: Filtering Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset + Memory Optimization
# - The `pd.to_datetime` method converts a **Series** to hold datetime values.
# - The `format` parameter informs pandas of the format that the times are stored in.
# - We pass symbols designating the segments of the string. For example, %m means "month" and %d means day.
# - The `dt` attribute reveals an object with many datetime-related attributes and methods.
# - The `dt.time` attribute extracts only the time from each value in a datetime **Series**.
# - Use the `astype` method to convert the values in a **Series** to another type.
# - The `parse_dates` parameter of `read_csv` is an alternate way to parse strings as datetimes.

# %%
employees = pd.read_csv('employees.csv')
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
employees.head(1)
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308    6.945
#
#   Senior Management       Team
# 0              True  Marketing

# %%
employees['Start Date'] = pd.to_datetime(employees['Start Date'], format='%m/%d/%Y')

# %%
pd.to_datetime(employees['Last Login Time'], format='%H:%M %p').dt.time
# Out:
# 0      12:42:00
# 1      06:53:00
# 2      11:17:00
# 3      01:00:00
# 4      04:47:00
#          ...
# 995    06:09:00
# 996    06:30:00
# 997    12:39:00
# 998    04:45:00
# 999    06:24:00
# Name: Last Login Time, Length: 1000, dtype: object

# %%
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format='%H:%M %p').dt.time
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees['Senior Management'] = employees['Senior Management'].astype(bool)

# %%
# vai fazer uma relação similar a chave estrangeira para as categorias unicas localizadas: Male/Female
employees['Gender'] = employees['Gender'].astype('category')

# %%
# antes: memory usage: 62.6+ KB
# agora: memory usage: 49.1+ KB
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees = pd.read_csv('employees.csv', parse_dates=['Start Date'], date_format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format='%H:%M %p').dt.time
employees['Senior Management'] = employees['Senior Management'].astype(bool)
employees['Gender'] = employees['Gender'].astype('category')
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# ## Filter A DataFrame  Based On A Condition
# - Pandas needs a **Series** of Booleans to perform a filter.
# - Pass the Boolean Series inside square brackets after the **DataFrame**.
# - We can generate a Boolean Series using a wide variety of operations (equality, inequality, less than, greater than, inclusion, etc)

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees[employees['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
employees[employees['Team'] == 'Finance']
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14        07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28        10:47:00  114796    6.796
# ..         ...     ...        ...             ...     ...      ...
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
employees[employees['Senior Management']]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %%
employees[employees['Salary'] > 100_000].sort_values(ascending=True, by='Salary')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 85      Jeremy    Male 2008-02-01        08:50:00  100238    3.887
# 261      Marie  Female 1995-08-06        01:58:00  100308   13.677
# 660       Mary     NaN 1986-12-24        07:02:00  100341    6.662
# 21     Matthew    Male 1995-09-05        02:12:00  100612   13.645
# 98        Tina  Female 2016-06-16        07:47:00  100705   16.961
# ..         ...     ...        ...             ...     ...      ...
# 160      Kathy  Female 2000-03-18        07:26:00  149563   16.991
# 186        NaN  Female 2005-02-23        09:50:00  149654    1.825
# 828    Cynthia  Female 2006-07-12        08:55:00  149684    7.864
# 429       Rose  Female 2015-05-28        08:40:00  149903    5.630
# 644  Katherine  Female 1996-08-13        12:21:00  149908   18.912
#
#      Senior Management             Team
# 85                True  Client Services
# 261              False          Product
# 660              False     Distribution
# 21               False        Marketing
# 98                True        Marketing
# ..                 ...              ...
# 160               True          Finance
# 186               True            Sales
# 828              False          Product
# 429              False  Human Resources
# 644              False          Finance
#
# [409 rows x 8 columns]

# %%
employees[employees['Start Date'] < '1985-01-01'].head()
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise  Female 1980-08-12        09:01:00   63241   15.132
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 18      Diana  Female 1981-10-23        10:27:00  132940   19.082
# 28      Terry    Male 1981-11-27        06:30:00  124008   13.464
# 37      Linda  Female 1981-10-19        08:49:00   57427    9.557
#
#     Senior Management             Team
# 10               True              NaN
# 12               True  Human Resources
# 18              False  Client Services
# 28               True  Client Services
# 37               True  Client Services

# %%
import datetime as dt
employees[employees['Last Login Time'] < dt.time(12, 0, 0)].head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18        01:35:00  115163   10.125
#
#    Senior Management             Team
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %% [markdown]
# ## Filter with More than One Condition (AND)
# - Add the `&` operator in between two Boolean **Series** to filter by multiple conditions.
# - We can assign the **Series** to variables to make the syntax more readable.

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
# females employees who work in Marketing
is_female = employees['Gender'] == 'Female'
is_in_marketing = employees['Team'] == 'Marketing'

# %%
employees[is_female & is_in_marketing].sort_values(by='First Name').head(10)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 627       Anne  Female 1984-11-21        12:30:00  128305   16.636
# 676      Annie  Female 1992-06-06        10:04:00  138925    9.801
# 894      Betty  Female 2002-11-19        10:40:00   37005    7.645
# 446     Cheryl  Female 1994-08-16        08:33:00   67150   15.850
# 625    Cynthia  Female 2015-06-29        06:38:00   82408    8.701
# 629      Debra  Female 1983-03-12        12:19:00   74911   19.513
# 675      Diane  Female 2009-10-30        06:56:00  130577   12.791
# 986      Donna  Female 1982-11-26        07:04:00   82871   17.999
# 331     Evelyn  Female 1983-09-03        01:58:00   36759   17.269
# 813     Evelyn  Female 2002-02-10        04:44:00  123621   19.767
#
#      Senior Management       Team
# 627              False  Marketing
# 676               True  Marketing
# 894               True  Marketing
# 446               True  Marketing
# 625               True  Marketing
# 629              False  Marketing
# 675              False  Marketing
# 986              False  Marketing
# 331               True  Marketing
# 813               True  Marketing

# %%
salary_over_100k = employees['Salary'] >= 100_000
employees[is_female & is_in_marketing & salary_over_100k].sort_values(by='First Name')
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 627        Anne  Female 1984-11-21        12:30:00  128305   16.636
# 676       Annie  Female 1992-06-06        10:04:00  138925    9.801
# 675       Diane  Female 2009-10-30        06:56:00  130577   12.791
# 813      Evelyn  Female 2002-02-10        04:44:00  123621   19.767
# 319  Jacqueline  Female 1981-11-25        03:01:00  145988   18.243
# 468      Janice  Female 1997-06-28        01:48:00  136032   10.696
# 490      Judith  Female 2007-11-23        01:22:00  117055    7.461
# 811      Judith  Female 1989-09-03        11:16:00  134048    6.818
# 656        Lisa  Female 1982-02-09        06:44:00  113592   17.108
# 305    Margaret  Female 1993-02-06        01:05:00  125220    3.733
# 158       Norma  Female 1999-02-28        08:45:00  114412    8.756
# 991        Rose  Female 2002-08-25        05:12:00  134505   11.051
# 881        Ruby  Female 1980-01-28        11:08:00  142868    6.318
# 585     Shirley  Female 1988-04-16        11:09:00  132156    2.754
# 140     Shirley  Female 1981-02-28        01:23:00  113850    1.854
# 98         Tina  Female 2016-06-16        07:47:00  100705   16.961
# 531    Virginia  Female 2010-05-02        09:10:00  123649   10.154
# 379         NaN  Female 2002-09-18        12:39:00  118906    4.537
#
#      Senior Management       Team
# 627              False  Marketing
# 676               True  Marketing
# 675              False  Marketing
# 813               True  Marketing
# 319              False  Marketing
# 468               True  Marketing
# 490              False  Marketing
# 811               True  Marketing
# 656               True  Marketing
# 305              False  Marketing
# 158               True  Marketing
# 991               True  Marketing
# 881              False  Marketing
# 585              False  Marketing
# 140              False  Marketing
# 98                True  Marketing
# 531               True  Marketing
# 379               True  Marketing

# %% [markdown]
# ## Filter with More than One Condition (OR)
# - Use the `|` operator in between two Boolean **Series** to filter by *either* condition.

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
# Senior Management OR started before  01-01-1990
is_senior_management = employees['Senior Management']
started_before_90s = employees['Start Date'] < '1990-01-01'
employees[is_senior_management | started_before_90s]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
# first name is robert who work in Client Services OR start date after 2016-06-01
is_robert = employees['First Name'] == 'Robert'
is_in_client_service = employees['Team'] == 'Client Services'
stared_2016_june = employees['Start Date'] > '2016-06-01'
employees[(is_robert & is_in_client_service) | stared_2016_june]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16        07:47:00  100705   16.961
# 387     Robert    Male 1994-10-29        04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15        12:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ## The isin Method
# - The `isin` **Series** method accepts a collection object like a list, tuple, or **Series**.
# - The method returns True for a row if its value is found in the collection.

# %%
selected_sort_employees = employees['Team'].isin(['Sales','Legal','Product'])
employees[selected_sort_employees].head(10)
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11      Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 17      Shawn    Male 1986-12-07        07:45:00  111737    6.414
# 19      Donna  Female 2010-07-22        03:48:00   81014    1.894
# 20       Lois     NaN 1995-04-22        07:18:00   64714    4.934
# 27      Scott     NaN 1991-07-11        06:58:00  122367    5.218
# 29   Benjamin    Male 2005-01-26        10:06:00   79529    7.008
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product
# 17              False  Product
# 19              False  Product
# 20               True    Legal
# 27              False    Legal
# 29               True    Legal

# %% [markdown]
# ## The isnull and notnull Methods
# - The `isnull` method returns True for `NaN` values in a **Series**.
# - The `notnull` method returns True for present values in a **Series**.

# %%
employees[employees['Team'].isnull()].head()
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12        09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14        04:19:00  125792    5.042
# 32        NaN    Male 1998-08-21        02:27:00  122340    6.417
# 91      James     NaN 2005-01-26        11:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
employees[employees['Team'].notnull()].head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18        01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %% [markdown]
# ## The between Method
# - The `between` method returns True if a **Series** value is found within its range.

# %%
employees = pd.read_csv('employees.csv', parse_dates=['Start Date'], date_format="%m/%d/%Y")
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'], format='%H:%M %p').dt.time
employees['Senior Management'] = employees['Senior Management'].astype(bool)
employees['Gender'] = employees['Gender'].astype('category')
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees[employees['Salary'].between(60_000, 70_000, inclusive='both')].sort_values(by='Salary')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 924    Deborah  Female 2003-11-11        04:53:00   60003    9.624
# 892    Brandon    Male 1995-10-23        12:04:00   60263    2.709
# 612      Julie     NaN 2000-10-21        01:15:00   60361    7.099
# 325    Russell    Male 2005-01-02        01:48:00   60388   17.885
# 709        NaN    Male 1995-04-07        04:32:00   60411   12.048
# ..         ...     ...        ...             ...     ...      ...
# 618      Peter    Male 1992-11-24        05:43:00   69297    1.268
# 455       Ruth  Female 2000-10-24        04:13:00   69579   18.029
# 597     Teresa  Female 1987-06-24        07:37:00   69740    8.294
# 352        NaN    Male 2011-10-09        09:29:00   69906    4.844
# 286       Todd    Male 1984-02-02        10:13:00   69989   10.985
#
#      Senior Management             Team
# 924              False  Client Services
# 892              False            Sales
# 612               True     Distribution
# 325              False  Client Services
# 709               True  Human Resources
# ..                 ...              ...
# 618              False          Finance
# 455               True  Human Resources
# 597              False     Distribution
# 352               True      Engineering
# 286               True          Finance
#
# [86 rows x 8 columns]

# %%
employees[employees['Start Date'].between('1991-01-01', '1992-01-01', inclusive='both')].sort_values(by='Start Date').head()
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 989     Justin    NaN 1991-02-10        04:58:00   38344    3.794
# 923      Irene    NaN 1991-02-28        10:23:00  135369    4.380
# 245     Victor   Male 1991-04-11        07:44:00   70817   17.138
# 783        NaN    NaN 1991-04-15        03:39:00  132505   13.592
# 725     Jeremy   Male 1991-05-19        01:40:00  131513    1.876
#
#      Senior Management                  Team
# 989              False                 Legal
# 923              False  Business Development
# 245              False           Engineering
# 783               True               Product
# 725               True               Finance

# %%
employees[employees['Last Login Time'].between(dt.time(8,30), dt.time(12,0), inclusive='both') & employees['First Name'].notnull()].sort_values(by='Last Login Time')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 345     Steven    Male 2006-11-21        08:30:00   83706    6.960
# 906    Frances  Female 2014-05-16        08:31:00   35884   17.667
# 350     Thomas     NaN 1995-08-31        08:31:00   41549    3.950
# 807       Mary  Female 2011-11-06        08:32:00  115057    2.089
# 446     Cheryl  Female 1994-08-16        08:33:00   67150   15.850
# ..         ...     ...        ...             ...     ...      ...
# 930      Nancy  Female 2001-09-10        11:57:00   85213    2.386
# 792       Anne     NaN 1996-04-18        11:57:00  122762    9.564
# 66       Nancy  Female 2012-12-15        11:57:00  125250    2.672
# 740    Russell     NaN 2009-05-09        11:59:00  149456    3.533
# 302       Adam    Male 2007-07-05        11:59:00   71276    5.027
#
#      Senior Management                  Team
# 345               True       Human Resources
# 906              False                 Sales
# 350              False                 Sales
# 807              False               Finance
# 446               True             Marketing
# ..                 ...                   ...
# 930               True             Marketing
# 792              False          Distribution
# 66                True  Business Development
# 740              False             Marketing
# 302               True       Human Resources
#
# [255 rows x 8 columns]

# %% [markdown]
# ## The duplicated Method
# - The `duplicated` method returns True if a **Series** value is a duplicate.
# - Pandas will mark one occurrence of a repeated value as a non-duplicate.
# - Use the `keep` parameter to designate whether the first or last occurrence of a repeated value should be considered the "non-duplicate".
# - Pass False to the `keep` parameter to mark all occurrences of repeated values as duplicates.
# - Use the tilde symbol (`~`) to invert a **Series's** values. Trues will become Falses, and Falses will become trues.

# %%
# tabela apenas com nomes duplicados e não vazios
# keep = 'first' >> primeiro valor duplicado permanece, demais desconsiderados.
employees[employees['First Name'].duplicated(keep=False) & employees['First Name'].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [924 rows x 8 columns]

# %%
employees[employees['First Name'].duplicated(keep='first')]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 23         NaN   Male 2012-06-14        04:19:00  125792    5.042
# 25         NaN   Male 2012-10-08        01:12:00   37076   18.576
# 32         NaN   Male 1998-08-21        02:27:00  122340    6.417
# 34       Jerry   Male 2004-01-10        12:56:00   95734   19.096
# 39         NaN   Male 2016-01-29        02:33:00  122173    7.797
# ..         ...    ...        ...             ...     ...      ...
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 23                True                   NaN
# 25                True       Client Services
# 32                True                   NaN
# 34               False       Client Services
# 39                True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [799 rows x 8 columns]

# %%
# Mostrar todos os valores unicos:
employees[~employees['First Name'].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18        09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19        03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07        10:47:00   93901   17.821
# 832      Keith    Male 2003-02-12        03:02:00  120672   19.467
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %% [markdown]
# ## The drop_duplicates Method
# - The `drop_duplicates` method deletes rows with duplicate values.
# - By default, it will remove a row if *all* of its values are shared with another row.
# - The `subset` parameter configures the columns to look for duplicate values within.
# - Pass a list to `subset` parameter to look for duplicates across multiple columns.

# %%
# confere se todos os dados da linha são iguais. Como todas as linhas tem algum valor diferente, retorna as mesmas 1.000 linhas.
employees.drop_duplicates()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
# primeiro valor localizado será considerado.
employees.drop_duplicates('Team') # default: keep='first'
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 8                True           Engineering
# 9                True  Business Development
# 12               True       Human Resources
# 13              False                 Sales
# 40               True          Distribution

# %%
employees.drop_duplicates('Team', keep=False) # todos se repetem, por isso vazia.
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
# ele pega o 'Senior Management' E 'Team' que diferem das demais linhas. Por isso 2 valores de cada.
employees.drop_duplicates(['Senior Management','Team'], keep='last').sort_values('Team')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 971    Patrick    Male 2002-12-30        02:01:00   75423    5.368
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 965  Catherine  Female 1989-09-25        01:31:00   68164   18.393
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 946        NaN  Female 1985-09-15        01:50:00  133472   16.941
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 984      Maria  Female 2011-10-15        04:53:00   43455   13.040
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 976     Denise  Female 1992-10-19        05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 986      Donna  Female 1982-11-26        07:04:00   82871   17.999
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 979     Ernest    Male 2013-07-20        06:41:00  142935   13.198
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 975      Susan  Female 1995-04-07        10:05:00   92436   12.467
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
# 912        Joe    Male 1998-12-08        10:28:00  126120    1.020
# 951        NaN  Female 2010-09-14        05:19:00  143638    9.662
#
#      Senior Management                  Team
# 971               True  Business Development
# 998              False  Business Development
# 965              False       Client Services
# 990               True       Client Services
# 946               True          Distribution
# 995              False          Distribution
# 993               True           Engineering
# 984              False           Engineering
# 996              False               Finance
# 992               True               Finance
# 988              False       Human Resources
# 982               True       Human Resources
# 976               True                 Legal
# 989              False                 Legal
# 986              False             Marketing
# 994               True             Marketing
# 979               True               Product
# 997              False               Product
# 975              False                 Sales
# 999               True                 Sales
# 912              False                   NaN
# 951               True                   NaN

# %% [markdown]
# ## The unique and nunique Methods
# - The `unique` method on a **Series** returns a collection of its unique values. The method does not exist on a **DataFrame**.
# - The `nunique` method returns a *count* of the number of unique values in the **Series**/**DataFrame**.
# - The `dropna` parameter configures whether to include or exclude missing (`NaN`) values.

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees['Gender'].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
# dropna=True >> desconsidera o NaN na contagem.
employees['Gender'].nunique(dropna=True)
# Out:
# 2

# %%
employees.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      542
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64
