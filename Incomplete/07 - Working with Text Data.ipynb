# %% [markdown]
# # Working with Text Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset (`chicago.csv`) is a collection of public sector employees in the city of Chicago.
# - Each row inclues the employee's name, position, department, and salary.

# %%
chicago = pd.read_csv('chicago.csv').dropna(how='all')
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
chicago.nunique()
# Out:
# Name                      31776
# Position Title             1093
# Department                   35
# Employee Annual Salary     1156
# dtype: int64

# %%
# 2 Department 32062 non-null >>> category
chicago['Department'] = chicago['Department'].astype('category')
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Common String Methods
# - A **Series** has a special `str` attribute that exposes an object with string methods.
# - Access the `str` attribute, then invoke the string method on the nested object.
# - Most method names will match their Python method equivalents (`upper`, `lower`, `title`, etc).

# %%
chicago['Position Title'].str.lower().head(10)
# Out:
# 0               water rate taker
# 1                 police officer
# 2                 police officer
# 3       chief contract expediter
# 4              civil engineer iv
# 5           asst to the alderman
# 6          general laborer - dss
# 7    traffic control aide-hourly
# 8     staff asst to the alderman
# 9            electrical mechanic
# Name: Position Title, dtype: object

# %%
chicago['Position Title'].str.title().head(10)
# Out:
# 0               Water Rate Taker
# 1                 Police Officer
# 2                 Police Officer
# 3       Chief Contract Expediter
# 4              Civil Engineer Iv
# 5           Asst To The Alderman
# 6          General Laborer - Dss
# 7    Traffic Control Aide-Hourly
# 8     Staff Asst To The Alderman
# 9            Electrical Mechanic
# Name: Position Title, dtype: object

# %%
chicago['Position Title'].str.len().head(10)
# Out:
# 0    16
# 1    14
# 2    14
# 3    24
# 4    17
# 5    20
# 6    21
# 7    27
# 8    26
# 9    19
# Name: Position Title, dtype: int64

# %%
chicago['Position Title'].str.lower().str.len().head()
# Out:
# 0    16
# 1    14
# 2    14
# 3    24
# 4    17
# Name: Position Title, dtype: int64

# %%
# remover espaços em branco (r - direita, l - esquerda, strip() - ambos):
chicago['Position Title'].str.lstrip().str.rstrip().head()
chicago['Position Title'].str.strip().head()
# Out:
# 0            WATER RATE TAKER
# 1              POLICE OFFICER
# 2              POLICE OFFICER
# 3    CHIEF CONTRACT EXPEDITER
# 4           CIVIL ENGINEER IV
# Name: Position Title, dtype: object

# %%
chicago['Department'].str.replace('MGMNT','MANAGEMENT').head()
# Out:
# 0    WATER MANAGEMENT
# 1              POLICE
# 2              POLICE
# 3    GENERAL SERVICES
# 4    WATER MANAGEMENT
# Name: Department, dtype: object

# %% [markdown]
# ## Filtering with String Methods
# - The `str.contains` method checks whether a substring exists anywhere in the string.
# - The `str.startswith` method checks whether a substring exists at the start of the string.
# - The `str.endswith` method checks whether a substring exists at the end of the string.

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
water_workers = chicago['Position Title'].str.lower().str.contains('water')
chicago[water_workers]
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#         Department Employee Annual Salary
# 0      WATER MGMNT              $90744.00
# 554    WATER MGMNT             $102440.00
# 671    WATER MGMNT              $82044.00
# 685    WATER MGMNT             $109272.00
# 702    WATER MGMNT             $102440.00
# ...            ...                    ...
# 29669  WATER MGMNT             $111192.00
# 30239  WATER MGMNT              $89676.00
# 30544  WATER MGMNT             $115704.00
# 30991  WATER MGMNT             $102440.00
# 31405  WATER MGMNT             $102440.00
#
# [111 rows x 4 columns]

# %%
starts_with_civil = chicago['Position Title'].str.lower().str.startswith('civil')
chicago[starts_with_civil]
# Out:
#                        Name      Position Title   Department  \
# 4       ABAD JR,  VICENTE M   CIVIL ENGINEER IV  WATER MGMNT
# 25     ABDULSATTAR,  MUDHAR   CIVIL ENGINEER II  WATER MGMNT
# 34       ABRAHAM,  GIRLEY T   CIVIL ENGINEER IV  WATER MGMNT
# 55       ABUTALEB,  AHMAD H   CIVIL ENGINEER II  WATER MGMNT
# 147        ADAMS,  TANERA C   CIVIL ENGINEER IV   TRANSPORTN
# ...                     ...                 ...          ...
# 31623         YANG,  LUYANG    CIVIL ENGINEER V   TRANSPORTN
# 31656         YEPEZ,  JESUS   CIVIL ENGINEER IV   TRANSPORTN
# 31662  YESUFU,  STEPHANIE A  CIVIL ENGINEER III   TRANSPORTN
# 31797       ZAKE,  JOSHUA S   CIVIL ENGINEER IV   TRANSPORTN
# 31935          ZHANG,  ANNE  CIVIL ENGINEER III   TRANSPORTN
#
#       Employee Annual Salary
# 4                 $106836.00
# 25                 $58536.00
# 34                $106836.00
# 55                 $89676.00
# 147               $106836.00
# ...                      ...
# 31623             $116784.00
# 31656             $106836.00
# 31662              $92784.00
# 31797             $106836.00
# 31935              $77364.00
#
# [70 rows x 4 columns]

# %%
ends_with_civil = chicago['Position Title'].str.lower().str.endswith('iv')
chicago[starts_with_civil & ends_with_civil]
# Out:
#                        Name     Position Title             Department  \
# 4       ABAD JR,  VICENTE M  CIVIL ENGINEER IV            WATER MGMNT
# 34       ABRAHAM,  GIRLEY T  CIVIL ENGINEER IV            WATER MGMNT
# 147        ADAMS,  TANERA C  CIVIL ENGINEER IV             TRANSPORTN
# 2394      BOLLAM,  ALFRED R  CIVIL ENGINEER IV             TRANSPORTN
# 4272    CASTILLA,  FERNANDO  CIVIL ENGINEER IV             TRANSPORTN
# 4536     CHAVES,  OSWALDO E  CIVIL ENGINEER IV             TRANSPORTN
# 5935     CRUZAT,  ERNESTO M  CIVIL ENGINEER IV              BUILDINGS
# 8025        ERRERA,  JOHN S  CIVIL ENGINEER IV             TRANSPORTN
# 10810      GRIFFIN,  KALI R  CIVIL ENGINEER IV             TRANSPORTN
# 11528        HARRIS,  ABABI  CIVIL ENGINEER IV             TRANSPORTN
# 12336      HILL,  JENELLE E  CIVIL ENGINEER IV             TRANSPORTN
# 13044     IDOWU,  BABATUNDE  CIVIL ENGINEER IV             TRANSPORTN
# 13134     ISADA,  CARLITO G  CIVIL ENGINEER IV             TRANSPORTN
# 14428        KARIM,  ENAMUL  CIVIL ENGINEER IV            WATER MGMNT
# 14720        KENT,  MOIRA K  CIVIL ENGINEER IV             TRANSPORTN
# 15565   LABRADOR,  ROBERT S  CIVIL ENGINEER IV             TRANSPORTN
# 17197    MALEKPOOR,  SOOREN  CIVIL ENGINEER IV             TRANSPORTN
# 17297      MANN,  CHARLES M  CIVIL ENGINEER IV            WATER MGMNT
# 19744       MORRIS,  WADE C  CIVIL ENGINEER IV             TRANSPORTN
# 21613  PALAPARTHI,  PETER R  CIVIL ENGINEER IV             TRANSPORTN
# 22413   PHILLIPS,  JEREMY A  CIVIL ENGINEER IV             TRANSPORTN
# 25329      SAMUEL,  JAQULEN  CIVIL ENGINEER IV             TRANSPORTN
# 25992         SEGAL,  ROMAN  CIVIL ENGINEER IV  COMMUNITY DEVELOPMENT
# 26015  SEIF-KASHANI,  HAMID  CIVIL ENGINEER IV            WATER MGMNT
# 26139       SHAPIRA,  SAM D  CIVIL ENGINEER IV            WATER MGMNT
# 26358          SHUM,  CHUCK  CIVIL ENGINEER IV             TRANSPORTN
# 26558        SINNO,  MAIZ R  CIVIL ENGINEER IV             TRANSPORTN
# 29724    VILLALON,  ROLANDO  CIVIL ENGINEER IV            WATER MGMNT
# 30030    WALSH,  CHARLENE S  CIVIL ENGINEER IV             TRANSPORTN
# 31592    WYTANIEC,  JEFFREY  CIVIL ENGINEER IV               AVIATION
# 31656         YEPEZ,  JESUS  CIVIL ENGINEER IV             TRANSPORTN
# 31797       ZAKE,  JOSHUA S  CIVIL ENGINEER IV             TRANSPORTN
#
#       Employee Annual Salary
# 4                 $106836.00
# 34                $106836.00
# 147               $106836.00
# 2394              $106836.00
# 4272              $106836.00
# 4536              $106836.00
# 5935              $106836.00
# 8025              $106836.00
# 10810             $106836.00
# 11528             $106836.00
# 12336              $81228.00
# 13044             $106836.00
# 13134             $106836.00
# 14428             $106836.00
# 14720              $88788.00
# 15565             $101280.00
# 17197             $106836.00
# 17297             $106836.00
# 19744              $75048.00
# 21613             $106836.00
# 22413             $106836.00
# 25329             $106836.00
# 25992              $92784.00
# 26015             $106836.00
# 26139              $71292.00
# 26358             $106836.00
# 26558             $106836.00
# 29724             $106836.00
# 30030              $84924.00
# 31592              $75048.00
# 31656             $106836.00
# 31797             $106836.00

# %% [markdown]
# ## String Methods on Index and Columns
# - Use the `index` and `columns` attributes to access the **DataFrame** index/column labels.
# - These objects support string methods via their own `str` attribute.

# %%
chicago = pd.read_csv('chicago.csv', index_col='Name').dropna(how='all').sort_index()
chicago['Department'] = chicago['Department'].astype('category')
chicago.head()
# Out:
#                                Position Title        Department  \
# Name
# AARON,  ELVIA J              WATER RATE TAKER       WATER MGMNT
# AARON,  JEFFERY M              POLICE OFFICER            POLICE
# AARON,  KARINA                 POLICE OFFICER            POLICE
# AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     Employee Annual Salary
# Name
# AARON,  ELVIA J                  $90744.00
# AARON,  JEFFERY M                $84450.00
# AARON,  KARINA                   $84450.00
# AARON,  KIMBERLEI R              $89880.00
# ABAD JR,  VICENTE M             $106836.00

# %%
chicago.index = chicago.index.str.strip().str.title()
chicago.head()
# Out:
#                                Position Title        Department  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     Employee Annual Salary
# Name
# Aaron,  Elvia J                  $90744.00
# Aaron,  Jeffery M                $84450.00
# Aaron,  Karina                   $84450.00
# Aaron,  Kimberlei R              $89880.00
# Abad Jr,  Vicente M             $106836.00

# %%
chicago.columns = chicago.columns.str.upper()
chicago.head()
# Out:
#                                POSITION TITLE        DEPARTMENT  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J                  $90744.00
# Aaron,  Jeffery M                $84450.00
# Aaron,  Karina                   $84450.00
# Aaron,  Kimberlei R              $89880.00
# Abad Jr,  Vicente M             $106836.00

# %% [markdown]
# ## The split Method
# - The `str.split` method splits a string by the occurrence of a delimiter. Pandas returns a **Series** of lists.
# - Use the `str.get` method to access a nested list element by its index position.

# %%
chicago = pd.read_csv('chicago.csv').dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago['Position Title'].str.split(' ').str.get(0).value_counts()
# Out:
# Position Title
# POLICE             10856
# FIREFIGHTER-EMT     1509
# SERGEANT            1186
# POOL                 918
# FIREFIGHTER          810
#                    ...
# PORTFOLIO              1
# SUPERVISOR             1
# SUPT                   1
# STRUCTURAL             1
# CORPORATION            1
# Name: count, Length: 320, dtype: int64

# %% [markdown]
# ## More Practice with Splits

# %%
chicago['Name'].str.title().str.split(', ').str.get(1).str.strip().str.split(' ').str.get(0).value_counts()
# Out:
# Name
# Michael     1153
# John         899
# James        676
# Robert       622
# Joseph       537
#             ...
# Russ           1
# Fabiola        1
# Jurdon         1
# Nateesha       1
# Lilya          1
# Name: count, Length: 5091, dtype: int64

# %%
def split_function(row):
    nome = row['Name'].split(',  ')
    nome = nome[1].split(' ')
    return nome[0].title()

chicago.apply(split_function, axis='columns').value_counts()
# Out:
# Michael     1153
# John         899
# James        676
# Robert       622
# Joseph       537
#             ...
# Russ           1
# Fabiola        1
# Jurdon         1
# Nateesha       1
# Lilya          1
# Name: count, Length: 5091, dtype: int64

# %% [markdown]
# ## The expand and n Parameters of the split Method
# - The `expand` parameter returns a **DataFrame** instead of a **Series** of lists.
# - The `n` parameter limits the number of splits.

# %%
chicago[['Last Name','First Name']] = chicago['Name'].str.split(',', expand=True)
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary Last Name     First Name
# 0              $90744.00     AARON        ELVIA J
# 1              $84450.00     AARON      JEFFERY M
# 2              $84450.00     AARON         KARINA
# 3              $89880.00     AARON    KIMBERLEI R
# 4             $106836.00   ABAD JR      VICENTE M

# %%
# reorganizar a ordem das colunas:
colunas_reordenadas = ['Name', 'Last Name', 'First Name', 'Position Title','Department','Employee Annual Salary','Last Name']
chicago = chicago[colunas_reordenadas]
chicago.head()
# Out:
#                   Name Last Name     First Name            Position Title  \
# 0      AARON,  ELVIA J     AARON        ELVIA J          WATER RATE TAKER
# 1    AARON,  JEFFERY M     AARON      JEFFERY M            POLICE OFFICER
# 2       AARON,  KARINA     AARON         KARINA            POLICE OFFICER
# 3  AARON,  KIMBERLEI R     AARON    KIMBERLEI R  CHIEF CONTRACT EXPEDITER
# 4  ABAD JR,  VICENTE M   ABAD JR      VICENTE M         CIVIL ENGINEER IV
#
#          Department Employee Annual Salary Last Name
# 0       WATER MGMNT              $90744.00     AARON
# 1            POLICE              $84450.00     AARON
# 2            POLICE              $84450.00     AARON
# 3  GENERAL SERVICES              $89880.00     AARON
# 4       WATER MGMNT             $106836.00   ABAD JR

# %%
chicago['Position Title'].str.split(' ', expand=True, n=1).head()
# Out:
#         0                   1
# 0   WATER          RATE TAKER
# 1  POLICE             OFFICER
# 2  POLICE             OFFICER
# 3   CHIEF  CONTRACT EXPEDITER
# 4   CIVIL         ENGINEER IV
