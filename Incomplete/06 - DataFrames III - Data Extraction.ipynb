# %% [markdown]
# # DataFrames III: Data Extraction

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset is a collection of all James Bond movies.

# %%
bond = pd.read_csv('jamesbond.csv')
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %%
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               27 non-null     object
#  1   Year               27 non-null     int64
#  2   Actor              27 non-null     object
#  3   Director           27 non-null     object
#  4   Box Office         27 non-null     float64
#  5   Budget             27 non-null     float64
#  6   Bond Actor Salary  20 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.6+ KB

# %% [markdown]
# ## The set_index and reset_index Methods
# - The index serves as the collection of primary identifiers/labels/entrypoints for the rows.
# - The fastest way to extract a row is from a sorted index by position/label.
# - Pandas uses index labels/values when merging different objects together.
# - The `set_index` method sets an existing column as the index of the **DataFrame**.
# - The `reset_index` method sets the standard ascending numeric index as the index of the **DataFrame**.

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond = bond.set_index('Film')
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only               1981     Roger Moore           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# A View to a Kill                 1985     Roger Moore           John Glen
# The Living Daylights             1987  Timothy Dalton           John Glen
# Licence to Kill                  1989  Timothy Dalton           John Glen
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# No Time to Die                   2021    Daniel Craig  Cary Joji Fukunaga
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# Live and Let Die                      460.3    30.8                NaN
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# Moonraker                             535.0    91.5                NaN
# For Your Eyes Only                    449.4    60.2                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# A View to a Kill                      275.2    54.5                9.1
# The Living Daylights                  313.5    68.8                5.2
# Licence to Kill                       250.9    56.7                7.9
# GoldenEye                             518.5    76.9                5.1
# Tomorrow Never Dies                   463.2   133.9               10.0
# The World Is Not Enough               439.5   158.3               13.5
# Die Another Day                       465.4   154.2               17.9
# Casino Royale                         581.5   145.3                3.3
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3               30.0
# No Time to Die                        774.2   301.0               25.0

# %%
bond = bond.reset_index()
bond[bond['Bond Actor Salary'].notnull()].sort_values(by='Bond Actor Salary')
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 14                        Octopussy  1983     Roger Moore           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 6        291.5    37.3                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 22       581.5   145.3                3.3
# 5        514.2    59.9                4.4
# 3        848.1    41.9                4.7
# 18       518.5    76.9                5.1
# 16       313.5    68.8                5.2
# 7        442.5    34.7                5.8
# 14       373.8    53.9                7.8
# 17       250.9    56.7                7.9
# 23       514.2   181.4                8.1
# 15       275.2    54.5                9.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 24       943.5   170.2               14.5
# 21       465.4   154.2               17.9
# 26       774.2   301.0               25.0
# 25       726.7   206.3               30.0

# %% [markdown]
# ## Retrieve Rows by Index Position with iloc Accessor
# - The `iloc` accessor retrieves one or more rows by index position.
# - Provide a pair of square brackets after the accessor.
# - `iloc` accepts single values, lists, and slices.

# %%
# com uma linha especifica, é uma Serie
bond.iloc[5]
# Out:
# Film                 You Only Live Twice
# Year                                1967
# Actor                       Sean Connery
# Director                   Lewis Gilbert
# Box Office                         514.2
# Budget                              59.9
# Bond Actor Salary                    4.4
# Name: 5, dtype: object

# %%
bond.iloc[[15,20]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %%
bond['Actor'].loc[0]
# Out:
# 'Sean Connery'

# %%
# Cria uma série com 'Actor' como índice e 'Film' como valor
bond_actor_serie = bond.set_index('Actor')['Film']
bond_actor_serie.loc['Sean Connery']
# Out:
# Actor
# Sean Connery                   Dr. No
# Sean Connery    From Russia with Love
# Sean Connery               Goldfinger
# Sean Connery              Thunderball
# Sean Connery      You Only Live Twice
# Sean Connery     Diamonds Are Forever
# Sean Connery    Never Say Never Again
# Name: Film, dtype: object

# %% [markdown]
# ## Retrieve Rows by Index Label with loc Accessor
# - The `loc` accessor retrieves one or more rows by index label.
# - Provide a pair of square brackets after the accessor.

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film').sort_values('Film')
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['A View to a Kill']
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.loc[['Casino Royale', 'Dr. No']].sort_values(by='Year')
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Dr. No         1962  Sean Connery    Terence Young       448.8     7.0
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Dr. No                       0.6
# Casino Royale                NaN
# Casino Royale                3.3

# %%
bond.loc['Diamonds Are Forever':'Goldeneye']
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1

# %%
bond.reset_index()
# Out:
#                                Film  Year           Actor            Director  \
# 0                  A View to a Kill  1985     Roger Moore           John Glen
# 1                     Casino Royale  2006    Daniel Craig     Martin Campbell
# 2                     Casino Royale  1967     David Niven          Ken Hughes
# 3              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 4                   Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 5                            Dr. No  1962    Sean Connery       Terence Young
# 6                For Your Eyes Only  1981     Roger Moore           John Glen
# 7             From Russia with Love  1963    Sean Connery       Terence Young
# 8                         GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 9                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 10                  Licence to Kill  1989  Timothy Dalton           John Glen
# 11                 Live and Let Die  1973     Roger Moore        Guy Hamilton
# 12                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
# 15                        Octopussy  1983     Roger Moore           John Glen
# 16  On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 17                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 18                          Skyfall  2012    Daniel Craig          Sam Mendes
# 19                          Spectre  2015    Daniel Craig          Sam Mendes
# 20             The Living Daylights  1987  Timothy Dalton           John Glen
# 21      The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 22             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 23          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 24                      Thunderball  1965    Sean Connery       Terence Young
# 25              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 26              You Only Live Twice  1967    Sean Connery       Lewis Gilbert
#
#     Box Office  Budget  Bond Actor Salary
# 0        275.2    54.5                9.1
# 1        581.5   145.3                3.3
# 2        315.0    85.0                NaN
# 3        442.5    34.7                5.8
# 4        465.4   154.2               17.9
# 5        448.8     7.0                0.6
# 6        449.4    60.2                NaN
# 7        543.8    12.6                1.6
# 8        518.5    76.9                5.1
# 9        820.4    18.6                3.2
# 10       250.9    56.7                7.9
# 11       460.3    30.8                NaN
# 12       535.0    91.5                NaN
# 13       380.0    86.0                NaN
# 14       774.2   301.0               25.0
# 15       373.8    53.9                7.8
# 16       291.5    37.3                0.6
# 17       514.2   181.4                8.1
# 18       943.5   170.2               14.5
# 19       726.7   206.3               30.0
# 20       313.5    68.8                5.2
# 21       334.0    27.7                NaN
# 22       533.0    45.1                NaN
# 23       439.5   158.3               13.5
# 24       848.1    41.9                4.7
# 25       463.2   133.9               10.0
# 26       514.2    59.9                4.4

# %% [markdown]
# ## Second Arguments to loc and iloc Accessors
# - The second value inside the square brackets targets the columns.
# - The `iloc` requires numeric positions for rows and columns.
# - The `loc` requires labels for rows and columns.

# %%
bond = bond.reset_index()
by_movie = bond.set_index('Film')
by_movie.sort_index()
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# No Time to Die                   2021    Daniel Craig  Cary Joji Fukunaga
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                        774.2   301.0               25.0
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3               30.0
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
by_movie.loc[['Die Another Day', 'You Only Live Twice'], 'Director':'Budget']
# Out:
#                           Director  Box Office  Budget
# Film
# Die Another Day       Lee Tamahori       465.4   154.2
# You Only Live Twice  Lewis Gilbert       514.2    59.9

# %%
by_year = bond.set_index('Year')['Film']
by_year
# Out:
# Year
# 1985                   A View to a Kill
# 2006                      Casino Royale
# 1967                      Casino Royale
# 1971               Diamonds Are Forever
# 2002                    Die Another Day
# 1962                             Dr. No
# 1981                 For Your Eyes Only
# 1963              From Russia with Love
# 1995                          GoldenEye
# 1964                         Goldfinger
# 1989                    Licence to Kill
# 1973                   Live and Let Die
# 1979                          Moonraker
# 1983              Never Say Never Again
# 2021                     No Time to Die
# 1983                          Octopussy
# 1969    On Her Majesty's Secret Service
# 2008                  Quantum of Solace
# 2012                            Skyfall
# 2015                            Spectre
# 1987               The Living Daylights
# 1974        The Man with the Golden Gun
# 1977               The Spy Who Loved Me
# 1999            The World Is Not Enough
# 1965                        Thunderball
# 1997                Tomorrow Never Dies
# 1967                You Only Live Twice
# Name: Film, dtype: object

# %%
# linha 4 (0-1-2-3), coluna 3 (0-1-2)
bond.iloc[3,2]
# Out:
# 'Sean Connery'

# %%
# [linhas], [colunas]
bond.iloc[[0,2],[2,4]]
# Out:
#          Actor  Box Office
# 0  Roger Moore       275.2
# 2  David Niven       315.0

# %% [markdown]
# ## Overwrite Value in a DataFrame
# - Use the `iloc` or `loc` accessor on the **DataFrame** to target a value, then provide the equal sign and a new value.

# %%
change_value = bond.iloc[:1]
change_value
# Out:
#                Film  Year        Actor   Director  Box Office  Budget  \
# 0  A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#    Bond Actor Salary
# 0                9.1

# %%
change_value.iloc[0,2]
# Out:
# 'Roger Moore'

# %%
change_value.iloc[0,2] = 'New Unkown Actor'
change_value
# Out:
#                Film  Year             Actor   Director  Box Office  Budget  \
# 0  A View to a Kill  1985  New Unkown Actor  John Glen       275.2    54.5
#
#    Bond Actor Salary
# 0                9.1

# %%
# cria um DF de index por nome de filme. Depois loc procura o nome 'index' desejado, na coluna desejada (por que é uma série com index filme)
# loc busca em Série e iloc 
bond_create_serie = pd.read_csv('jamesbond.csv', index_col='Film')
bond_create_serie.loc['From Russia with Love','Actor']
# Out:
# 'Sean Connery'

# %%
bond_many_columns = pd.read_csv('jamesbond.csv', usecols=['Film','Actor','Year'])
bond_many_columns.head()
# Out:
#                     Film  Year         Actor
# 0                 Dr. No  1962  Sean Connery
# 1  From Russia with Love  1963  Sean Connery
# 2             Goldfinger  1964  Sean Connery
# 3            Thunderball  1965  Sean Connery
# 4          Casino Royale  1967   David Niven

# %% [markdown]
# ##  Overwrite Multiple Values in a DataFrame
# - The `replace` method replaces all occurrences of a **Series** value with another value (think of it like "Find and Replace").
# - To overwrite multiple values in a **DataFrame**, remember to use an accessor on the **DataFrame** itself.
# - Accessors like `loc` and `iloc` can accept Boolean Series. Use them to target the values to overwrite.

# %%
bond['Actor'] = bond['Actor'].replace('Sean Connery', 'Sir Sean Connery')
bond
# Out:
#                                Film  Year             Actor  \
# 0                  A View to a Kill  1985  New Unkown Actor
# 1                     Casino Royale  2006      Daniel Craig
# 2                     Casino Royale  1967       David Niven
# 3              Diamonds Are Forever  1971  Sir Sean Connery
# 4                   Die Another Day  2002    Pierce Brosnan
# 5                            Dr. No  1962  Sir Sean Connery
# 6                For Your Eyes Only  1981       Roger Moore
# 7             From Russia with Love  1963  Sir Sean Connery
# 8                         GoldenEye  1995    Pierce Brosnan
# 9                        Goldfinger  1964  Sir Sean Connery
# 10                  Licence to Kill  1989    Timothy Dalton
# 11                 Live and Let Die  1973       Roger Moore
# 12                        Moonraker  1979       Roger Moore
# 13            Never Say Never Again  1983  Sir Sean Connery
# 14                   No Time to Die  2021      Daniel Craig
# 15                        Octopussy  1983       Roger Moore
# 16  On Her Majesty's Secret Service  1969    George Lazenby
# 17                Quantum of Solace  2008      Daniel Craig
# 18                          Skyfall  2012      Daniel Craig
# 19                          Spectre  2015      Daniel Craig
# 20             The Living Daylights  1987    Timothy Dalton
# 21      The Man with the Golden Gun  1974       Roger Moore
# 22             The Spy Who Loved Me  1977       Roger Moore
# 23          The World Is Not Enough  1999    Pierce Brosnan
# 24                      Thunderball  1965  Sir Sean Connery
# 25              Tomorrow Never Dies  1997    Pierce Brosnan
# 26              You Only Live Twice  1967  Sir Sean Connery
#
#               Director  Box Office  Budget  Bond Actor Salary
# 0            John Glen       275.2    54.5                9.1
# 1      Martin Campbell       581.5   145.3                3.3
# 2           Ken Hughes       315.0    85.0                NaN
# 3         Guy Hamilton       442.5    34.7                5.8
# 4         Lee Tamahori       465.4   154.2               17.9
# 5        Terence Young       448.8     7.0                0.6
# 6            John Glen       449.4    60.2                NaN
# 7        Terence Young       543.8    12.6                1.6
# 8      Martin Campbell       518.5    76.9                5.1
# 9         Guy Hamilton       820.4    18.6                3.2
# 10           John Glen       250.9    56.7                7.9
# 11        Guy Hamilton       460.3    30.8                NaN
# 12       Lewis Gilbert       535.0    91.5                NaN
# 13      Irvin Kershner       380.0    86.0                NaN
# 14  Cary Joji Fukunaga       774.2   301.0               25.0
# 15           John Glen       373.8    53.9                7.8
# 16       Peter R. Hunt       291.5    37.3                0.6
# 17        Marc Forster       514.2   181.4                8.1
# 18          Sam Mendes       943.5   170.2               14.5
# 19          Sam Mendes       726.7   206.3               30.0
# 20           John Glen       313.5    68.8                5.2
# 21        Guy Hamilton       334.0    27.7                NaN
# 22       Lewis Gilbert       533.0    45.1                NaN
# 23       Michael Apted       439.5   158.3               13.5
# 24       Terence Young       848.1    41.9                4.7
# 25  Roger Spottiswoode       463.2   133.9               10.0
# 26       Lewis Gilbert       514.2    59.9                4.4

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film').sort_index()

# %%
bond[bond['Actor'] == 'Sean Connery'].loc['From Russia with Love':'Goldfinger']
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
is_sean_connery = bond['Actor'] == 'Sean Connery'
bond.loc[is_sean_connery, "Actor"]
# Out:
# Film
# Diamonds Are Forever     Sean Connery
# Dr. No                   Sean Connery
# From Russia with Love    Sean Connery
# Goldfinger               Sean Connery
# Never Say Never Again    Sean Connery
# Thunderball              Sean Connery
# You Only Live Twice      Sean Connery
# Name: Actor, dtype: object

# %%
bond.loc[is_sean_connery, "Actor"] = 'Sir Sean Connery'
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# Moonraker                        1979       Roger Moore       Lewis Gilbert
# Never Say Never Again            1983  Sir Sean Connery      Irvin Kershner
# No Time to Die                   2021      Daniel Craig  Cary Joji Fukunaga
# Octopussy                        1983       Roger Moore           John Glen
# On Her Majesty's Secret Service  1969    George Lazenby       Peter R. Hunt
# Quantum of Solace                2008      Daniel Craig        Marc Forster
# Skyfall                          2012      Daniel Craig          Sam Mendes
# Spectre                          2015      Daniel Craig          Sam Mendes
# The Living Daylights             1987    Timothy Dalton           John Glen
# The Man with the Golden Gun      1974       Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977       Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999    Pierce Brosnan       Michael Apted
# Thunderball                      1965  Sir Sean Connery       Terence Young
# Tomorrow Never Dies              1997    Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967  Sir Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                        774.2   301.0               25.0
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3               30.0
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame
# - The `rename` method accepts a dictionary for either its `columns` or `index` parameters.
# - The dictionary keys represent the existing names and the values represent the new names.
# - We can replace all columns by overwriting the **DataFrame's** `columns` attribute.

# %%
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(columns={
    "Year":"Year of Release",
    "Box Office":"Revenue"
    }).head()
# Out:
#                       Year of Release             Actor         Director  \
# Film
# A View to a Kill                 1985       Roger Moore        John Glen
# Casino Royale                    2006      Daniel Craig  Martin Campbell
# Casino Royale                    1967       David Niven       Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery     Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan     Lee Tamahori
#
#                       Revenue  Budget  Bond Actor Salary
# Film
# A View to a Kill        275.2    54.5                9.1
# Casino Royale           581.5   145.3                3.3
# Casino Royale           315.0    85.0                NaN
# Diamonds Are Forever    442.5    34.7                5.8
# Die Another Day         465.4   154.2               17.9

# %%
swaps = {
    'Casino Royale':'Cassino Royale',
    'Diamonds Are Forever':'Diamantes são eternos',
    'Die Another Day':'Um novo dia para morrer',
}
bond[bond['Bond Actor Salary'].notnull()].rename(index=swaps).head()
# Out:
#                          Year             Actor         Director  Box Office  \
# Film
# A View to a Kill         1985       Roger Moore        John Glen       275.2
# Cassino Royale           2006      Daniel Craig  Martin Campbell       581.5
# Diamantes são eternos    1971  Sir Sean Connery     Guy Hamilton       442.5
# Um novo dia para morrer  2002    Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                   1962  Sir Sean Connery    Terence Young       448.8
#
#                          Budget  Bond Actor Salary
# Film
# A View to a Kill           54.5                9.1
# Cassino Royale            145.3                3.3
# Diamantes são eternos      34.7                5.8
# Um novo dia para morrer   154.2               17.9
# Dr. No                      7.0                0.6

# %%
# bond.columns[2] ==> pandas não permite alterar nome usando essa sintaxe. Apenas alterando todo as colunas, conforme abaixo.
bond.columns = ['Ano','Ator', 'Diretor','Caixa','Budget','Salário Bond']
bond.head()
# Out:
#                        Ano              Ator          Diretor  Caixa  Budget  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen  275.2    54.5
# Casino Royale         2006      Daniel Craig  Martin Campbell  581.5   145.3
# Casino Royale         1967       David Niven       Ken Hughes  315.0    85.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton  442.5    34.7
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori  465.4   154.2
#
#                       Salário Bond
# Film
# A View to a Kill               9.1
# Casino Royale                  3.3
# Casino Royale                  NaN
# Diamonds Are Forever           5.8
# Die Another Day               17.9

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame
# - The `drop` method deletes one or more rows/columns from a **DataFrame**.
# - Pass the `index` or `columns` parameters a list of the column names to remove.
# - The `pop` method removes and returns a single **Series** (it mutates the **DataFrame** in the process).
# - Python's `del` keyword also removes a single **Series**.

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film').sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.drop(columns=['Box Office', 'Budget'])
bond.drop(index=['No Time to Die',"Casino Royale"])
bond.drop(index=['No Time to Die',"Casino Royale"], columns=['Box Office', 'Budget'])
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Bond Actor Salary
# Film
# A View to a Kill                               9.1
# Diamonds Are Forever                           5.8
# Die Another Day                               17.9
# Dr. No                                         0.6
# For Your Eyes Only                             NaN
# From Russia with Love                          1.6
# GoldenEye                                      5.1
# Goldfinger                                     3.2
# Licence to Kill                                7.9
# Live and Let Die                               NaN
# Moonraker                                      NaN
# Never Say Never Again                          NaN
# Octopussy                                      7.8
# On Her Majesty's Secret Service                0.6
# Quantum of Solace                              8.1
# Skyfall                                       14.5
# Spectre                                       30.0
# The Living Daylights                           5.2
# The Man with the Golden Gun                    NaN
# The Spy Who Loved Me                           NaN
# The World Is Not Enough                       13.5
# Thunderball                                    4.7
# Tomorrow Never Dies                           10.0
# You Only Live Twice                            4.4

# %%
# rodando o POP, ele já altera no dataframe original. DROP permite fazer apenas na cópia.
bond.pop('Year')
bond.head()
# Out:
#                                Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill         Roger Moore        John Glen       275.2    54.5
# Casino Royale           Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale            David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever    Sean Connery     Guy Hamilton       442.5    34.7
# Die Another Day       Pierce Brosnan     Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %%
# faz o mesmo que o POP. Altera o df original.
del bond['Actor']

# %%
bond.head()
# Out:
#                              Director  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill            John Glen       275.2    54.5                9.1
# Casino Royale         Martin Campbell       581.5   145.3                3.3
# Casino Royale              Ken Hughes       315.0    85.0                NaN
# Diamonds Are Forever     Guy Hamilton       442.5    34.7                5.8
# Die Another Day          Lee Tamahori       465.4   154.2               17.9

# %% [markdown]
# ## Create Random Sample with the sample Method
# - The `sample` method returns a specified one or more random rows from the **DataFrame**.
# - Customize the `axis` parameter to extract random columns.

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film').sort_index()

# %%
# n indices aleatórios
bond.sample(n=5)
# Out:
#                          Year           Actor         Director  Box Office  \
# Film
# The Living Daylights     1987  Timothy Dalton        John Glen       313.5
# The World Is Not Enough  1999  Pierce Brosnan    Michael Apted       439.5
# A View to a Kill         1985     Roger Moore        John Glen       275.2
# Casino Royale            2006    Daniel Craig  Martin Campbell       581.5
# Goldfinger               1964    Sean Connery     Guy Hamilton       820.4
#
#                          Budget  Bond Actor Salary
# Film
# The Living Daylights       68.8                5.2
# The World Is Not Enough   158.3               13.5
# A View to a Kill           54.5                9.1
# Casino Royale             145.3                3.3
# Goldfinger                 18.6                3.2

# %%
bond.sample(n=5, axis='rows')
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# Moonraker                1979     Roger Moore       Lewis Gilbert       535.0
# Skyfall                  2012    Daniel Craig          Sam Mendes       943.5
# Spectre                  2015    Daniel Craig          Sam Mendes       726.7
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
#
#                          Budget  Bond Actor Salary
# Film
# The World Is Not Enough   158.3               13.5
# Moonraker                  91.5                NaN
# Skyfall                   170.2               14.5
# Spectre                   206.3               30.0
# Tomorrow Never Dies       133.9               10.0

# %%
bond.sample(n=2, axis='columns').head()
# Out:
#                                Actor  Budget
# Film
# A View to a Kill         Roger Moore    54.5
# Casino Royale           Daniel Craig   145.3
# Casino Royale            David Niven    85.0
# Diamonds Are Forever    Sean Connery    34.7
# Die Another Day       Pierce Brosnan   154.2

# %% [markdown]
# ## The nsmallest and nlargest Methods
# - The `nlargest` method returns a specified number of rows with the largest values from a given column.
# - The `nsmallest` method returns rows with the smallest values from a given column.
# - The `nlargest` and `nsmallest` methods are more efficient than sorting the entire **DataFrame**.

# %%
# 4 filmes com maiores Box Office:
bond.sort_values(by='Box Office', ascending=False).head(4)
# Out:
#                 Year         Actor            Director  Box Office  Budget  \
# Film
# Skyfall         2012  Daniel Craig          Sam Mendes       943.5   170.2
# Thunderball     1965  Sean Connery       Terence Young       848.1    41.9
# Goldfinger      1964  Sean Connery        Guy Hamilton       820.4    18.6
# No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2   301.0
#
#                 Bond Actor Salary
# Film
# Skyfall                      14.5
# Thunderball                   4.7
# Goldfinger                    3.2
# No Time to Die               25.0

# %%
bond.nlargest(n=4,columns='Box Office')
# Out:
#                 Year         Actor            Director  Box Office  Budget  \
# Film
# Skyfall         2012  Daniel Craig          Sam Mendes       943.5   170.2
# Thunderball     1965  Sean Connery       Terence Young       848.1    41.9
# Goldfinger      1964  Sean Connery        Guy Hamilton       820.4    18.6
# No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2   301.0
#
#                 Bond Actor Salary
# Film
# Skyfall                      14.5
# Thunderball                   4.7
# Goldfinger                    3.2
# No Time to Die               25.0

# %%
bond['Box Office'].nlargest(4)
# Out:
# Film
# Skyfall           943.5
# Thunderball       848.1
# Goldfinger        820.4
# No Time to Die    774.2
# Name: Box Office, dtype: float64

# %%
bond.nsmallest(n=3,columns='Bond Actor Salary')
bond['Bond Actor Salary'].nsmallest(3)
# Out:
# Film
# Dr. No                             0.6
# On Her Majesty's Secret Service    0.6
# From Russia with Love              1.6
# Name: Bond Actor Salary, dtype: float64

# %% [markdown]
# ## Filtering with the where Method
# - Similar to square brackets or `loc`, the `where` method filters the original `DataFrame` with a Boolean Series.
# - Pandas will populate rows that do **not** match the criteria with `NaN` values.
# - Leaving in the `NaN` values can be advantageous for certain merge and visualization operations.

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
is_sean_connery = bond['Actor'] == 'Sean Connery'
bond[is_sean_connery]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond[bond.where(is_sean_connery)['Bond Actor Salary'].notnull()].sort_values(by=['Director','Box Office'], ascending=[True,False])
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# You Only Live Twice    1967  Sean Connery  Lewis Gilbert       514.2    59.9
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
#
#                        Bond Actor Salary
# Film
# Goldfinger                           3.2
# Diamonds Are Forever                 5.8
# You Only Live Twice                  4.4
# Thunderball                          4.7
# From Russia with Love                1.6
# Dr. No                               0.6

# %% [markdown]
# ## The apply Method with DataFrames
# - The `apply` method invokes a function on every column or every row in the **DataFrame**.
# - Pass the uninvoked function as the first argument to the `apply` method.
# - Pass the `axis` parameter an argument of `"columns"` to invoke the function on every row.
# - Pandas will pass in the row's values as a **Series** object. We can use accessors like `loc` and `iloc` to extract the column's values for that row.

# %%
bond['Actor'].apply(len).head()
# Out:
# Film
# A View to a Kill        11
# Casino Royale           12
# Casino Royale           11
# Diamonds Are Forever    12
# Die Another Day         14
# Name: Actor, dtype: int64

# %%
def rank_movie(row):
    year = row.loc['Year']
    actor = row.loc['Actor']
    budget = row.loc['Budget']
    if year >= 1980 and year < 1990:
        return "Great 80's flick"
    if actor == 'Pierce Brosnan':
        return 'the best Bond Ever'
    if budget > 100:
        return 'Expensive Movie, fun'
    return 'No comment'

bond.apply(rank_movie, axis='columns')
# Out:
# Film
# A View to a Kill                       Great 80's flick
# Casino Royale                      Expensive Movie, fun
# Casino Royale                                No comment
# Diamonds Are Forever                         No comment
# Die Another Day                      the best Bond Ever
# Dr. No                                       No comment
# For Your Eyes Only                     Great 80's flick
# From Russia with Love                        No comment
# GoldenEye                            the best Bond Ever
# Goldfinger                                   No comment
# Licence to Kill                        Great 80's flick
# Live and Let Die                             No comment
# Moonraker                                    No comment
# Never Say Never Again                  Great 80's flick
# No Time to Die                     Expensive Movie, fun
# Octopussy                              Great 80's flick
# On Her Majesty's Secret Service              No comment
# Quantum of Solace                  Expensive Movie, fun
# Skyfall                            Expensive Movie, fun
# Spectre                            Expensive Movie, fun
# The Living Daylights                   Great 80's flick
# The Man with the Golden Gun                  No comment
# The Spy Who Loved Me                         No comment
# The World Is Not Enough              the best Bond Ever
# Thunderball                                  No comment
# Tomorrow Never Dies                  the best Bond Ever
# You Only Live Twice                          No comment
# dtype: object

# %%
def rank_movie(row):
    year = row.loc['Year']
    actor = row.loc['Actor']
    budget = row.loc['Budget']
    string = ''
    if year >= 1980 and year < 1990:
        string += "Great 80's flick"
    if actor == 'Pierce Brosnan':
        string += 'the best Bond Ever'
    if budget > 100:
        string += 'Expensive Movie, fun'
    if len(string) > 0:
        return string
    else:
        return 'No comment'

# Function to apply to each column or row >> axis : {0 or 'index', 1 or 'columns'}, default 0
bond.apply(rank_movie, axis='columns')
# Out:
# Film
# A View to a Kill                                         Great 80's flick
# Casino Royale                                        Expensive Movie, fun
# Casino Royale                                                  No comment
# Diamonds Are Forever                                           No comment
# Die Another Day                    the best Bond EverExpensive Movie, fun
# Dr. No                                                         No comment
# For Your Eyes Only                                       Great 80's flick
# From Russia with Love                                          No comment
# GoldenEye                                              the best Bond Ever
# Goldfinger                                                     No comment
# Licence to Kill                                          Great 80's flick
# Live and Let Die                                               No comment
# Moonraker                                                      No comment
# Never Say Never Again                                    Great 80's flick
# No Time to Die                                       Expensive Movie, fun
# Octopussy                                                Great 80's flick
# On Her Majesty's Secret Service                                No comment
# Quantum of Solace                                    Expensive Movie, fun
# Skyfall                                              Expensive Movie, fun
# Spectre                                              Expensive Movie, fun
# The Living Daylights                                     Great 80's flick
# The Man with the Golden Gun                                    No comment
# The Spy Who Loved Me                                           No comment
# The World Is Not Enough            the best Bond EverExpensive Movie, fun
# Thunderball                                                    No comment
# Tomorrow Never Dies                the best Bond EverExpensive Movie, fun
# You Only Live Twice                                            No comment
# dtype: object
