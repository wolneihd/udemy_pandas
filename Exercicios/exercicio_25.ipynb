# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
import pandas as pd

# %%
# This challenge includes a the_office.csv dataset.
# It is a listing of all episodes in the popular American sitcom The Office.
# The dataset has 7 columns:
# Season, Episode, Name, Director, Writer, Airdate, Viewership
# Import the the_office.csv file into a DataFrame. 
# Tell pandas to parse the values in the Airdate column as datetime values.
# Finally, assign the imported DataFrame to an 'office' variable.
office = pd.read_csv('the_office.csv', parse_dates=['Airdate'])
office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Season      201 non-null    int64
#  1   Episode     201 non-null    int64
#  2   Name        201 non-null    object
#  3   Director    201 non-null    object
#  4   Writer      201 non-null    object
#  5   Airdate     201 non-null    datetime64[ns]
#  6   Viewership  201 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 11.1+ KB

# %%
# CHALLENGE 1:
# Find all episodes that were EITHER in Season 4
# OR directed by Harold Ramis
# Assign the resulting DataFrame to a 'season_4_or_harold' variable.
season_4 = office['Season'] == 4
directed_by_harold = office['Director'] == 'Harold Ramis'
season_4_or_harold = office[directed_by_harold | season_4]
season_4_or_harold.head()
# Out:
#     Season  Episode                  Name      Director  \
# 37       3       10  A Benihana Christmas  Harold Ramis
# 38       3       11  A Benihana Christmas  Harold Ramis
# 47       3       20       Safety Training  Harold Ramis
# 50       3       23          Beach Games†  Harold Ramis
# 53       4        1               Fun Run  Greg Daniels
#
#                              Writer    Airdate  Viewership
# 37                 Jennifer Celotta 2006-12-14        9.07
# 38                 Jennifer Celotta 2006-12-14        8.44
# 47                      B. J. Novak 2007-04-12        7.71
# 50  Jennifer Celotta & Greg Daniels 2007-05-10        7.20
# 53                     Greg Daniels 2007-09-27        9.70

# %%
# CHALLENGE 2:
# Find all episodes that EITHER had a Viewership less than 4
# OR aired on/after January 1st, 2013.
# Assign the resulting DataFrame to a 'low_viewership_or_later_airdate' variable.
viewership_less_4 = office['Viewership'] < 4
aired_on_or_after_2013 = office['Airdate'] >= '2013-01-01'
low_viewership_or_later_airdate = office[viewership_less_4 & aired_on_or_after_2013]
low_viewership_or_later_airdate
# Out:
#      Season  Episode              Name          Director  \
# 189       9       14         Vandalism          Lee Kirk
# 192       9       17          The Farm  Paul Lieberstein
# 193       9       18            Promos  Jennifer Celotta
# 194       9       19     Stairmageddon         Matt Sohn
# 195       9       20    Paper Airplane      Jesse Peretz
# 196       9       21  Livin' the Dream     Jeffrey Blitz
#
#                                     Writer    Airdate  Viewership
# 189                         Owen Ellickson 2013-01-31        3.97
# 192                       Paul Lieberstein 2013-03-14        3.54
# 193                          Tim McAuliffe 2013-04-04        3.44
# 194                           Dan Sterling 2013-04-11        3.83
# 195  Halsted Sullivan & Warren Lieberstein 2013-04-25        3.25
# 196                   Niki Schwartz-Wright 2013-05-02        3.51

# %%
# CHALLENGE 3:
# Find all episodes that EITHER the 9th episode of their season
# OR had an episode Name of "Niagara"
# Assign the resulting DataFrame to a 'ninth_or_niagara' variable.
season_with_9th_episode = office['Episode'] == 9
name_episode_niagara = office['Name'] == 'Niagara'
ninth_or_niagara = office[season_with_9th_episode | name_episode_niagara]
ninth_or_niagara
# Out:
#      Season  Episode                Name           Director  \
# 14        2        9  Email Surveillance          Paul Feig
# 36        3        9         The Convict      Jeffrey Blitz
# 61        4        9            Local Ad      Jason Reitman
# 80        5        9          Frame Toby      Jason Reitman
# 103       6        4             Niagara          Paul Feig
# 104       6        5             Niagara          Paul Feig
# 108       6        9         Double Date        Seth Gordon
# 134       7        9           WUPHF.com       Danny Leiner
# 160       8        9     Mrs. California     Charlie Grandy
# 184       9        9    Dwight Christmas  Charles McDougall
#
#                                Writer    Airdate  Viewership
# 14                   Jennifer Celotta 2005-11-22        8.10
# 36   Ricky Gervais & Stephen Merchant 2006-11-30        9.07
# 61                        B. J. Novak 2007-10-25        8.98
# 80                       Mindy Kaling 2008-11-20        8.40
# 103       Greg Daniels & Mindy Kaling 2009-10-08        9.42
# 104       Greg Daniels & Mindy Kaling 2009-10-08        9.42
# 108                    Charlie Grandy 2009-11-05        7.94
# 134                       Aaron Shure 2010-11-18        7.28
# 160                       Dan Greaney 2011-12-01        5.71
# 184                    Robert Padnick 2012-12-06        4.16
