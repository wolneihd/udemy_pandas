# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
import pandas as pd

# %%
# This challenge includes a the_office.csv dataset.
# It is a listing of all episodes in the popular American sitcom The Office.
# The dataset has 7 columns:
# Season, Episode, Name, Director, Writer, Airdate, Viewership
# Import the the_office.csv fille into a DataFrame. 
# Tell pandas to parse the values in the Airdate column as datetime values.
# Finally, assign the imported DataFrame to an 'office' variable.
office = pd.read_csv('the_office.csv', parse_dates=['Airdate'], date_format='%B %d, %Y')
office.head()
# Out:
#    Season  Episode           Name         Director  \
# 0       1        1          Pilot       Ken Kwapis
# 1       1        2  Diversity Day       Ken Kwapis
# 2       1        3    Health Care  Ken Whittingham
# 3       1        4   The Alliance     Bryan Gordon
# 4       1        5     Basketball     Greg Daniels
#
#                                               Writer    Airdate  Viewership
# 0  Ricky Gervais & Stephen Merchant and Greg Daniels 2005-03-24        11.2
# 1                                        B. J. Novak 2005-03-29         6.0
# 2                                   Paul Lieberstein 2005-04-05         5.8
# 3                                      Michael Schur 2005-04-12         5.4
# 4                                       Greg Daniels 2005-04-19         5.0

# %%
office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Season      201 non-null    int64
#  1   Episode     201 non-null    int64
#  2   Name        201 non-null    object
#  3   Director    201 non-null    object
#  4   Writer      201 non-null    object
#  5   Airdate     201 non-null    datetime64[ns]
#  6   Viewership  201 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 11.1+ KB

# %%
# CHALLENGE 1:
# Find all episodes with a Writer of "Greg Daniels"
# Assign the resulting DataFrame to a 'written_by_greg' variable.
written_by_greg = office["Writer"] == "Greg Daniels"
office[written_by_greg]
# Out:
#      Season  Episode                 Name           Director        Writer  \
# 4         1        5           Basketball       Greg Daniels  Greg Daniels
# 10        2        5            Halloween          Paul Feig  Greg Daniels
# 16        2       11         Booze Cruise         Ken Kwapis  Greg Daniels
# 26        2       21  Conflict Resolution  Charles McDougall  Greg Daniels
# 28        3        1       Gay Witch Hunt         Ken Kwapis  Greg Daniels
# 53        4        1              Fun Run       Greg Daniels  Greg Daniels
# 54        4        2              Fun Run       Greg Daniels  Greg Daniels
# 147       7       22    Goodbye, Michael†          Paul Feig  Greg Daniels
# 176       9        1             New Guys       Greg Daniels  Greg Daniels
# 199       9       24               Finale         Ken Kwapis  Greg Daniels
# 200       9       25               Finale         Ken Kwapis  Greg Daniels
#
#        Airdate  Viewership
# 4   2005-04-19        5.00
# 10  2005-10-18        8.00
# 16  2006-01-05        8.70
# 26  2006-05-04        7.40
# 28  2006-09-21        9.11
# 53  2007-09-27        9.70
# 54  2007-09-27        9.70
# 147 2011-04-28        8.42
# 176 2012-09-20        4.28
# 199 2013-05-16        5.69
# 200 2013-05-16        5.69

# %%
# CHALLENGE 2:
# Find all episodes BEFORE season 8 (not including season 8)
# Assign the resulting DataFrame to a 'good_episodes' variable
good_episodes = office['Season'] < 8
office[good_episodes]
# Out:
#      Season  Episode                                 Name         Director  \
# 0         1        1                                Pilot       Ken Kwapis
# 1         1        2                        Diversity Day       Ken Kwapis
# 2         1        3                          Health Care  Ken Whittingham
# 3         1        4                         The Alliance     Bryan Gordon
# 4         1        5                           Basketball     Greg Daniels
# ..      ...      ...                                  ...              ...
# 147       7       22                    Goodbye, Michael†        Paul Feig
# 148       7       23                     The Inner Circle        Matt Sohn
# 149       7       24  Dwight K. Schrute, (Acting) Manager      Troy Miller
# 150       7       25                     Search Committee    Jeffrey Blitz
# 151       7       26                     Search Committee    Jeffrey Blitz
#
#                                                 Writer    Airdate  Viewership
# 0    Ricky Gervais & Stephen Merchant and Greg Daniels 2005-03-24       11.20
# 1                                          B. J. Novak 2005-03-29        6.00
# 2                                     Paul Lieberstein 2005-04-05        5.80
# 3                                        Michael Schur 2005-04-12        5.40
# 4                                         Greg Daniels 2005-04-19        5.00
# ..                                                 ...        ...         ...
# 147                                       Greg Daniels 2011-04-28        8.42
# 148                                     Charlie Grandy 2011-05-05        6.90
# 149                                     Justin Spitzer 2011-05-12        6.45
# 150                                   Paul Lieberstein 2011-05-19        7.29
# 151                                   Paul Lieberstein 2011-05-19        7.29
#
# [152 rows x 7 columns]

# %%
# CHALLENGE 3:
# Find all episodes that aired before 1/1/2008.
# Assign the resulting DataFrame to an 'early_episodes' variable.
early_episodes = office['Airdate'] < '2008-01-01'
office[early_episodes].sort_values(by='Airdate')
# Out:
#     Season  Episode            Name          Director  \
# 0        1        1           Pilot        Ken Kwapis
# 1        1        2   Diversity Day        Ken Kwapis
# 2        1        3     Health Care   Ken Whittingham
# 3        1        4    The Alliance      Bryan Gordon
# 4        1        5      Basketball      Greg Daniels
# ..     ...      ...             ...               ...
# 60       4        8           Money  Paul Lieberstein
# 61       4        9        Local Ad     Jason Reitman
# 62       4       10     Branch Wars       Joss Whedon
# 63       4       11    Survivor Man         Paul Feig
# 64       4       12  The Deposition     Julian Farino
#
#                                                Writer    Airdate  Viewership
# 0   Ricky Gervais & Stephen Merchant and Greg Daniels 2005-03-24       11.20
# 1                                         B. J. Novak 2005-03-29        6.00
# 2                                    Paul Lieberstein 2005-04-05        5.80
# 3                                       Michael Schur 2005-04-12        5.40
# 4                                        Greg Daniels 2005-04-19        5.00
# ..                                                ...        ...         ...
# 60                                   Paul Lieberstein 2007-10-18        8.50
# 61                                        B. J. Novak 2007-10-25        8.98
# 62                                       Mindy Kaling 2007-11-01        8.39
# 63                                       Steve Carell 2007-11-08        8.29
# 64                                       Lester Lewis 2007-11-15        8.86
#
# [65 rows x 7 columns]
